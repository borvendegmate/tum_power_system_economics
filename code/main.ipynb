# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prices = pd.read_csv("../data/prices.csv")
capacity = pd.read_csv("../data/capacity.csv")

# %%
prices.head()
# Out:
#      Date  NYCA  GHIJ    NYC    LI
# 0  May-23  4.90  5.24  17.75  7.05
# 1  Apr-23  1.00  1.10   1.10  1.65
# 2  Mar-23  2.17  2.17   2.17  2.17
# 3  Feb-23  4.00  4.00   4.00  4.00
# 4  Jan-23  2.69  2.69   2.69  2.87

# %%
capacity.head()
# Out:
#      Date          gas     coal     oil
# 0  Jan-17 -1093.158667  665.732   14.56
# 1  Feb-17 -1272.158667  777.732 -118.24
# 2  Mar-17 -1158.358667  569.732 -118.24
# 3  Apr-17 -1150.658667  569.732 -107.54
# 4  May-17 -1129.058667  569.732 -129.14

# %%
df = prices.set_index("Date").join(capacity.set_index("Date"))
df = df.dropna()

# %%
df.head()
# Out:
#         NYCA  GHIJ   NYC    LI         gas     coal   oil
# Date
# Mar-23  2.17  2.17  2.17  2.17  756.941333 -540.768 -9.44
# Feb-23  4.00  4.00  4.00  4.00  746.941333 -540.768 -9.64
# Jan-23  2.69  2.69  2.69  2.87  792.141333 -540.768 -9.24
# Dec-22  1.80  1.80  1.80  1.88  786.941333 -540.768 -9.84
# Nov-22  1.15  1.22  1.39  1.19  786.941333 -540.768 -9.84

# %%
sns.pairplot(df)
