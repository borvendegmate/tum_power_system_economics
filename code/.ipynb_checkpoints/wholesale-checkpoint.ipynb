# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
years = range(2006, 2024)

li = []
for year in years:
    df = pd.read_csv(f"../data/dam/OASIS_Day-Ahead_Market_Zonal_LBMP_{year}.csv")
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame['Eastern Date Hour Time Zone'].unique()
# Out:
# array(['EST', 'EDT'], dtype=object)

# %%
frame['Date'] = pd.to_datetime(frame['Eastern Date Hour'])

# %%
frame.head()
# Out:
#      Eastern Date Hour Eastern Date Hour Time Zone Zone Name  Zone PTID  \
# 0  2006/01/01 00:00:00                         EST    CAPITL      61757
# 1  2006/01/01 00:00:00                         EST    CENTRL      61754
# 2  2006/01/01 00:00:00                         EST    DUNWOD      61760
# 3  2006/01/01 00:00:00                         EST    GENESE      61753
# 4  2006/01/01 00:00:00                         EST       H Q      61844
#
#    DAM Zonal LBMP  DAM Zonal Losses  DAM Zonal Congestion  \
# 0           54.72              2.75                  0.00
# 1           49.83             -2.13                  0.00
# 2           55.60              3.64                  0.00
# 3           47.86             -4.11                  0.00
# 4           54.42             -0.10                 -2.56
#
#    DAM Zonal Price Version       Date
# 0                        1 2006-01-01
# 1                        1 2006-01-01
# 2                        1 2006-01-01
# 3                        1 2006-01-01
# 4                        1 2006-01-01

# %%
prices_est = frame[frame['Eastern Date Hour Time Zone'] == 'EST']
prices_est = prices_est.pivot(index = 'Date', columns = 'Zone Name', values = 'DAM Zonal LBMP')

prices_edt = frame[frame['Eastern Date Hour Time Zone'] == 'EDT']
prices_edt = prices_edt.pivot(index = 'Date', columns = 'Zone Name', values = 'DAM Zonal LBMP')

# %%
prices = pd.concat([prices_est, prices_edt], axis=0)

# %%
prices.head()
# Out:
# Zone Name            CAPITL  CENTRL  DUNWOD  GENESE    H Q  HUD VL  LONGIL  \
# Date
# 2006-01-01 00:00:00   54.72   49.83   55.60   47.86  54.42   55.18   88.07
# 2006-01-01 01:00:00   48.07   43.92   48.90   42.31  46.18   48.62   85.96
# 2006-01-01 02:00:00   45.91   41.87   46.48   40.51  48.44   46.22   81.96
# 2006-01-01 03:00:00   45.81   41.78   46.33   40.43  47.51   46.07   81.15
# 2006-01-01 04:00:00   44.87   41.10   45.30   39.81  47.54   45.00   81.24
#
# Zone Name            MHK VL  MILLWD  N.Y.C.  NORTH    NPX    O H    PJM   WEST
# Date
# 2006-01-01 00:00:00   51.96   55.44   56.07  51.70  54.77  45.00  46.66  45.47
# 2006-01-01 01:00:00   45.90   48.80   49.31  46.09  48.25  39.50  40.42  39.78
# 2006-01-01 02:00:00   43.72   46.44   46.88  43.94  46.00  38.01  38.45  38.19
# 2006-01-01 03:00:00   43.58   46.25   46.73  43.80  45.90  38.02  38.72  38.24
# 2006-01-01 04:00:00   42.73   45.21   45.69  42.94  44.91  37.54  38.48  37.75

# %%
monthly = prices.resample('M').mean()

# %%
ax = monthly.plot()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title("Monthly day-ahead prices in the NYISO and neighbouring balancing zones in $/MWh")
# Out:
# Text(0.5, 1.0, 'Monthly day-ahead prices in the NYISO and neighbouring balancing zones in $/MWh')

# %%
monthly.columns
# Out:
# Index(['CAPITL', 'CENTRL', 'DUNWOD', 'GENESE', 'H Q', 'HUD VL', 'LONGIL',
#        'MHK VL', 'MILLWD', 'N.Y.C.', 'NORTH', 'NPX', 'O H', 'PJM', 'WEST'],
#       dtype='object', name='Zone Name')

# %%
localities = pd.DataFrame()
localities['NYCA'] = monthly[['CAPITL', 'CENTRL', 'DUNWOD', 'GENESE', 'WEST', 'HUD VL', 'LONGIL',
       'MHK VL', 'MILLWD', 'N.Y.C.', 'NORTH']].mean(axis = 1)
localities['NYC'] = monthly['N.Y.C.']
localities['LI'] = monthly['LONGIL']
localities['G-J'] = monthly[['HUD VL', 'MILLWD', 'DUNWOD', 'N.Y.C.']].mean(axis = 1)

# %%
localities.head()
# Out:
#                  NYCA        NYC         LI        G-J
# Date
# 2006-01-31  71.063608  77.892083  90.131169  75.150094
# 2006-02-28  66.316258  72.224866  93.183423  69.285882
# 2006-03-31  61.063118  69.330995  83.718024  63.911855
# 2006-04-30  60.440474  66.244896  87.301433  63.217510
# 2006-05-31  57.136391  62.234140  75.975242  60.800796

# %%
ax = localities.plot()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title("Monthly average day-ahead prices per locality in $/MWh")
# Out:
# Text(0.5, 1.0, 'Monthly average day-ahead prices per locality in $/MWh')

# %%
fuels = pd.read_csv('../data/fuels/fuels.csv')
cols = ['coal', 'petroleum', 'natural gas']
fuels = (fuels
         .set_index(pd.to_datetime(fuels['Date'], 
                                   dayfirst=True))
         [['United States : coal dollars per million Btu',
           'United States : petroleum liquids dollars per million Btu',
           'United States : natural gas dollars per million Btu']]
        )
fuels.columns = cols

fuels.head()
# Out:
#             coal  petroleum  natural gas
# Date
# 2008-01-01  1.88      14.61         8.19
# 2008-02-01  1.89      15.03         8.58
# 2008-03-01  1.93      14.67         9.25
# 2008-04-01  1.97      14.65         9.89
# 2008-05-01  2.04      17.13        10.73

# %%
ax = fuels.plot()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title("Monthly average fuel prices in $/mmBtu")
# Out:
# Text(0.5, 1.0, 'Monthly average fuel prices in $/mmBtu')

# %%
capacity = pd.read_csv('../data/cap/capacity.csv')
capacity = capacity.set_index('Date')

# %%
ax = capacity.plot()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title("Spot capacity prices in $/kW-month")
# Out:
# Text(0.5, 1.0, 'Spot capacity prices in $/kW-month')

# %%
fuels.to_csv('fuels.csv')
localities.to_csv('dam.csv')
capacity.to_csv('cap.csv')
