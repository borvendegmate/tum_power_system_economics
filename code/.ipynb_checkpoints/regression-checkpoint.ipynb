# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

sns.set_style('whitegrid')

# %%
#prices

fuels = pd.read_csv('fuels.csv')
cap = pd.read_csv('cap.csv')

# %%
dam = pd.read_csv('dam.csv')

dam['Date'] = pd.to_datetime(dam['Date'])

dam = (dam
       .set_index(dam['Date']) # pd.to_datetime(dam['Date'])
       .drop('Date', axis = 1)
       )

dam = dam.reset_index().rename(columns = {'Date': 'date_old'})
dam['date_new'] = dam['date_old'] - pd.offsets.MonthEnd(0) - pd.offsets.MonthBegin(1)

dam = dam.drop('date_old', axis = 1).rename(columns = {'date_new': 'Date'}).set_index('Date')

dam.columns = ['nyca_dam', 'nyc_dam', 'li_dam', 'gj_dam']

# %%
fuels = (fuels
         .set_index(pd.to_datetime(fuels['Date']))
         .drop('Date', axis = 1)
        )

# %%
cap = (cap
       .set_index(pd.to_datetime(cap['Date'], format = '%b-%y'))
       .drop('Date', axis = 1)
       )
cap.columns = ['nyca_icap', 'gj_icap', 'nyc_icap', 'li_icap']

# %%
locs = ['GJ', 'LI', 'NYC']

gen = {}

for loc in locs:
    gen[loc] = pd.read_csv(f'../data\Generating_Capacity_{loc}_11-23.csv')
    gen[loc] = (gen[loc]
                .set_index(pd.to_datetime(gen[loc]['Date']))
                .drop('Date', axis = 1))

gen['NYCA'] = pd.read_csv('../data\Generating_Capacity_NYCA_04-23.csv')
gen['NYCA'] = (gen['NYCA']
               .set_index(pd.to_datetime(gen['NYCA']['Date']))
               .drop('Date', axis = 1))

# %%
# calculate sum of generating capacity excluding natural gas power plants
locs = ['GJ', 'LI', 'NYC', 'NYCA']
for loc in locs:
    gen[loc]['Sum_woGas (' + str(loc) + ')'] = gen[loc]['Sum (' + str(loc) + ')']-gen[loc]['Gas (' + str(loc) + ')']

# %%
gen['NYCA'].head()
# Out:
#             Gas (NYCA)  Coal (NYCA)  Oil (NYCA)  Renewables (NYCA)  \
# Date
# 2004-01-01     17021.3       4246.3      8225.1             6375.9
# 2005-01-01     19196.7       4278.8      8209.2             6515.3
# 2006-01-01     19512.2       4314.0      8240.2             6711.5
# 2007-01-01     19512.2       4314.0      8240.2             6785.7
# 2008-01-01     19605.2       4258.0      8240.2             7123.5
#
#             Others (NYCA)  Sum (NYCA)  Sum_woGas (NYCA)
# Date
# 2004-01-01         5611.2     35868.6           18847.3
# 2005-01-01         5611.2     38200.0           19003.3
# 2006-01-01         5611.2     38777.9           19265.7
# 2007-01-01         5708.1     38852.1           19339.9
# 2008-01-01         5708.1     39226.9           19621.7

# %%
ucap = pd.read_csv("../data/Monthly_UCAP_Requirements.csv")
ucap = (ucap
        .set_index(pd.to_datetime(ucap['Date']))
        .drop('Date', axis = 1)
        )

# %%
above = pd.read_csv('../data/Monthly_Percent_Cleared_Above.csv')
above = (above
        .set_index(pd.to_datetime(above['Date']))
        .drop('Date', axis = 1)
        )

# %%
# shift generating capacity by two years (approximate construction time of a power plant)
#locs = ['GJ', 'LI', 'NYC', 'NYCA']
#gen_shifted = {}
#for loc in locs:
#    gen_shifted[loc] = gen[loc].shift(periods=3, freq="y").shift(periods=1, freq="d")

# %%
# shift icap/dam prices by one year

nyca_icap_1 = pd.DataFrame()
nyca_icap_1['ICAP-1'] = cap['nyca_icap'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

nyca_dam_1 = pd.DataFrame()
nyca_dam_1['DAM-1'] = dam['nyca_dam'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

plt.plot(nyca_dam_1['DAM-1'])
plt.plot(dam['nyca_dam'])

# %%
plt.plot(nyca_icap_1['ICAP-1'])
plt.plot(cap['nyca_icap'])

# %%
nyc_icap_1 = pd.DataFrame()
nyc_icap_1['ICAP-1'] = cap['nyc_icap'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

nyc_dam_1 = pd.DataFrame()
nyc_dam_1['DAM-1'] = dam['nyc_dam'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

gj_icap_1 = pd.DataFrame()
gj_icap_1['ICAP-1'] = cap['gj_icap'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

gj_dam_1 = pd.DataFrame()
gj_dam_1['DAM-1'] = dam['gj_dam'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

li_icap_1 = pd.DataFrame()
li_icap_1['ICAP-1'] = cap['li_icap'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

li_dam_1 = pd.DataFrame()
li_dam_1['DAM-1'] = dam['li_dam'].shift(periods=-13, freq="m").shift(periods=1, freq="d")

# %%
nyca_icap_2 = pd.DataFrame()
nyca_icap_2['ICAP-2'] = cap['nyca_icap'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

nyca_dam_2 = pd.DataFrame()
nyca_dam_2['DAM-2'] = dam['nyca_dam'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

nyc_icap_2 = pd.DataFrame()
nyc_icap_2['ICAP-2'] = cap['nyc_icap'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

nyc_dam_2 = pd.DataFrame()
nyc_dam_2['DAM-2'] = dam['nyc_dam'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

gj_icap_2 = pd.DataFrame()
gj_icap_2['ICAP-2'] = cap['gj_icap'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

gj_dam_2 = pd.DataFrame()
gj_dam_2['DAM-2'] = dam['gj_dam'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

li_icap_2 = pd.DataFrame()
li_icap_2['ICAP-2'] = cap['li_icap'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

li_dam_2 = pd.DataFrame()
li_dam_2['DAM-2'] = dam['li_dam'].shift(periods=-25, freq="m").shift(periods=1, freq="d")

# %%
nyca_icap_3 = pd.DataFrame()
nyca_icap_3['ICAP-3'] = cap['nyca_icap'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

nyca_dam_3 = pd.DataFrame()
nyca_dam_3['DAM-3'] = dam['nyca_dam'].shift(periods=-37, freq="m").shift(periods=1, freq="d")


nyc_icap_3 = pd.DataFrame()
nyc_icap_3['ICAP-3'] = cap['nyc_icap'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

nyc_dam_3 = pd.DataFrame()
nyc_dam_3['DAM-3'] = dam['nyc_dam'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

gj_icap_3 = pd.DataFrame()
gj_icap_3['ICAP-3'] = cap['gj_icap'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

gj_dam_3 = pd.DataFrame()
gj_dam_3['DAM-3'] = dam['gj_dam'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

li_icap_3 = pd.DataFrame()
li_icap_3['ICAP-3'] = cap['li_icap'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

li_dam_3 = pd.DataFrame()
li_dam_3['DAM-3'] = dam['li_dam'].shift(periods=-37, freq="m").shift(periods=1, freq="d")

# %%
nyca_icap_4 = pd.DataFrame()
nyca_icap_4['ICAP-4'] = cap['nyca_icap'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

nyca_dam_4 = pd.DataFrame()
nyca_dam_4['DAM-4'] = dam['nyca_dam'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

nyc_icap_4 = pd.DataFrame()
nyc_icap_4['ICAP-4'] = cap['nyc_icap'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

nyc_dam_4 = pd.DataFrame()
nyc_dam_4['DAM-4'] = dam['nyc_dam'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

gj_icap_4 = pd.DataFrame()
gj_icap_4['ICAP-4'] = cap['gj_icap'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

gj_dam_4 = pd.DataFrame()
gj_dam_4['DAM-4'] = dam['gj_dam'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

li_icap_4 = pd.DataFrame()
li_icap_4['ICAP-4'] = cap['li_icap'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

li_dam_4 = pd.DataFrame()
li_dam_4['DAM-4'] = dam['li_dam'].shift(periods=-49, freq="m").shift(periods=1, freq="d")

# %%
nyca_reg = (gen['NYCA']
            .join(cap)
            .join(fuels)
            .join(dam)
            .join(above)
            .join(ucap)
            .join(nyca_icap_1)
            .join(nyca_icap_2)
            .join(nyca_icap_3)
            .join(nyca_icap_4)
            .join(nyca_dam_1)
            .join(nyca_dam_2)
            .join(nyca_dam_3)
            .join(nyca_dam_4)
            .dropna(axis = 0)
           )

# %%
nyc_reg = (gen['NYC']
            .join(cap)
            .join(fuels)
            .join(dam)
            .join(above)
            .join(ucap)
            .join(nyc_icap_1)
            .join(nyc_icap_2)
            .join(nyc_icap_3)
            .join(nyc_icap_4)
            .join(nyc_dam_1)
            .join(nyc_dam_2)
            .join(nyc_dam_3)
            .join(nyc_dam_4)
            .dropna(axis = 0)
            )

# %%
gj_reg = (gen['GJ']
            .join(cap)
            .join(fuels)
            .join(dam)
            .join(above)
            .join(ucap)
            .join(gj_icap_1)
            .join(gj_icap_2)
            .join(gj_icap_3)
            .join(gj_icap_4)
            .join(gj_dam_1)
            .join(gj_dam_2)
            .join(gj_dam_3)
            .join(gj_dam_4)
            .dropna(axis = 0)
            )

# %%
li_reg = (gen['LI']
            .join(cap)
            .join(fuels)
            .join(dam)
            .join(above)
            .join(ucap)
            .join(li_icap_1)
            .join(li_icap_2)
            .join(li_icap_3)
            .join(li_icap_4)
            .join(li_dam_1)
            .join(li_dam_2)
            .join(li_dam_3)
            .join(li_dam_4)
            .dropna(axis = 0)
            )

# %%
nyca_reg.columns
# Out:
# Index(['Gas (NYCA)', 'Coal (NYCA)', 'Oil (NYCA)', 'Renewables (NYCA)',
#        'Others (NYCA)', 'Sum (NYCA)', 'Sum_woGas (NYCA)', 'nyca_icap',
#        'gj_icap', 'nyc_icap', 'li_icap', 'coal', 'petroleum', 'natural gas',
#        'nyca_dam', 'nyc_dam', 'li_dam', 'gj_dam', 'Cleared Above NYCA (%)',
#        'Cleared Above GJ (%)', 'Cleared Above NYC (%)', 'Cleared Above LI (%)',
#        'UCAP NYCA (MW)', 'UCAP GJ (MW)', 'UCAP NYC (MW)', 'UCAP LI (MW)',
#        'ICAP-1', 'ICAP-2', 'ICAP-3', 'ICAP-4', 'DAM-1', 'DAM-2', 'DAM-3',
#        'DAM-4'],
#       dtype='object')

# %%
nyca_df = nyca_reg[['Gas (NYCA)', 
                    #'Coal (NYCA)',
                    # 'Oil (NYCA)', 
                    #'Renewables (NYCA)', 
                    #'Others (NYCA)',
                    #'Sum (NYCA)',
                    'Sum_woGas (NYCA)',
                    #'nyca_icap',
                    'natural gas', 
                    #'nyca_dam', 
                    #'Cleared Above NYCA (%)', 
                    'UCAP NYCA (MW)',
                    'ICAP-1', 'ICAP-2', 'ICAP-3', 'ICAP-4',
                    'DAM-1', 'DAM-2', 'DAM-3', 'DAM-4'
                    ]]

# %%
nyca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31 entries, 2015-01-01 to 2019-05-01
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Gas (NYCA)        31 non-null     float64
#  1   Sum_woGas (NYCA)  31 non-null     float64
#  2   natural gas       31 non-null     float64
#  3   UCAP NYCA (MW)    31 non-null     float64
#  4   ICAP-1            31 non-null     float64
#  5   ICAP-2            31 non-null     float64
#  6   ICAP-3            31 non-null     float64
#  7   ICAP-4            31 non-null     float64
#  8   DAM-1             31 non-null     float64
#  9   DAM-2             31 non-null     float64
#  10  DAM-3             31 non-null     float64
#  11  DAM-4             31 non-null     float64
# dtypes: float64(12)
# memory usage: 3.1 KB

# %%
sns.heatmap(nyca_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x = nyca_df.loc[:, nyca_df.columns != 'Gas (NYCA)']
y = nyca_df['Gas (NYCA)']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Gas (NYCA)   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     7.426
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):           8.37e-05
# Time:                        16:33:24   Log-Likelihood:                -197.61
# No. Observations:                  31   AIC:                             419.2
# Df Residuals:                      19   BIC:                             436.4
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.002e+04   1.09e+04      1.842      0.081   -2730.033    4.28e+04
# Sum_woGas (NYCA)     0.6727      0.552      1.218      0.238      -0.483       1.829
# natural gas        -11.5565    134.709     -0.086      0.933    -293.506     270.393
# UCAP NYCA (MW)      -0.1600      0.191     -0.838      0.413      -0.560       0.240
# ICAP-1            -196.6809     50.693     -3.880      0.001    -302.782     -90.580
# ICAP-2              56.9232     53.827      1.058      0.304     -55.739     169.585
# ICAP-3              83.3194     30.999      2.688      0.015      18.437     148.202
# ICAP-4              62.3095     54.081      1.152      0.264     -50.883     175.502
# DAM-1                0.1921      4.268      0.045      0.965      -8.740       9.124
# DAM-2               -4.2163      3.348     -1.259      0.223     -11.225       2.792
# DAM-3                1.0256      2.833      0.362      0.721      -4.904       6.955
# DAM-4               -3.7975      1.993     -1.905      0.072      -7.969       0.374
# ==============================================================================
# Omnibus:                        0.308   Durbin-Watson:                   1.485
# Prob(Omnibus):                  0.857   Jarque-Bera (JB):                0.429
# Skew:                           0.203   Prob(JB):                        0.807
# Kurtosis:                       2.591   Cond. No.                     1.27e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.27e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
nyc_df = nyc_reg[['Gas (NYC)', 
                    #'Coal (NYC)',
                    # 'Oil (NYC)', 
                    #'Renewables (NYC)', 
                    #'Others (NYC)',
                    #'Sum (NYC)',
                    'Sum_woGas (NYC)',
                    #'nyc_icap',
                    'natural gas', 
                    #'nyc_dam', 
                    #'Cleared Above NYC (%)', 
                    #'UCAP NYC (MW)',
                    'ICAP-1', 'ICAP-2', 'ICAP-3', 'ICAP-4',
                    'DAM-1', 'DAM-2', 'DAM-3', 'DAM-4'
                    ]]

# %%
nyc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31 entries, 2015-01-01 to 2019-05-01
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gas (NYC)        31 non-null     float64
#  1   Sum_woGas (NYC)  31 non-null     float64
#  2   natural gas      31 non-null     float64
#  3   ICAP-1           31 non-null     float64
#  4   ICAP-2           31 non-null     float64
#  5   ICAP-3           31 non-null     float64
#  6   ICAP-4           31 non-null     float64
#  7   DAM-1            31 non-null     float64
#  8   DAM-2            31 non-null     float64
#  9   DAM-3            31 non-null     float64
#  10  DAM-4            31 non-null     float64
# dtypes: float64(11)
# memory usage: 2.9 KB

# %%
sns.heatmap(nyc_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x = nyc_df.loc[:, nyc_df.columns != 'Gas (NYC)']
y = nyc_df['Gas (NYC)']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Gas (NYC)   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     2.907
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):             0.0203
# Time:                        16:33:25   Log-Likelihood:                -166.43
# No. Observations:                  31   AIC:                             354.9
# Df Residuals:                      20   BIC:                             370.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            9066.3040    325.221     27.877      0.000    8387.904    9744.704
# Sum_woGas (NYC)     0.1587      0.578      0.275      0.786      -1.047       1.365
# natural gas       -34.1964     35.638     -0.960      0.349    -108.536      40.143
# ICAP-1             -0.0638      8.152     -0.008      0.994     -17.069      16.941
# ICAP-2             -7.6291      5.805     -1.314      0.204     -19.738       4.480
# ICAP-3              6.5073      2.883      2.257      0.035       0.494      12.521
# ICAP-4             -0.0766      7.670     -0.010      0.992     -16.077      15.924
# DAM-1               1.1031      1.421      0.776      0.447      -1.862       4.068
# DAM-2               0.2216      1.005      0.220      0.828      -1.875       2.318
# DAM-3               0.4158      0.831      0.500      0.622      -1.319       2.150
# DAM-4              -0.5968      0.600     -0.994      0.332      -1.849       0.656
# ==============================================================================
# Omnibus:                        4.093   Durbin-Watson:                   1.187
# Prob(Omnibus):                  0.129   Jarque-Bera (JB):                2.576
# Skew:                           0.617   Prob(JB):                        0.276
# Kurtosis:                       3.685   Cond. No.                     1.60e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
gj_df = gj_reg[['Gas (GJ)', 
                    #'Coal (GJ)',
                    # 'Oil (GJ)', 
                    #'Renewables (GJ)', 
                    #'Others (GJ)',
                    #'Sum (GJ)',
                    'Sum_woGas (GJ)',
                    #'gj_icap',
                    'natural gas', 
                    #'gj_dam', 
                    #'Cleared Above GJ (%)', 
                    #'UCAP GJ (MW)',
                    'ICAP-1', 'ICAP-2', 'ICAP-3', 'ICAP-4',
                    'DAM-1', 'DAM-2', 'DAM-3', 'DAM-4'
                    ]]

# %%
gj_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31 entries, 2015-01-01 to 2019-05-01
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gas (GJ)        31 non-null     float64
#  1   Sum_woGas (GJ)  31 non-null     float64
#  2   natural gas     31 non-null     float64
#  3   ICAP-1          31 non-null     float64
#  4   ICAP-2          31 non-null     float64
#  5   ICAP-3          31 non-null     float64
#  6   ICAP-4          31 non-null     float64
#  7   DAM-1           31 non-null     float64
#  8   DAM-2           31 non-null     float64
#  9   DAM-3           31 non-null     float64
#  10  DAM-4           31 non-null     float64
# dtypes: float64(11)
# memory usage: 2.9 KB

# %%
sns.heatmap(gj_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x = gj_df.loc[:, gj_df.columns != 'Gas (GJ)']
y = gj_df['Gas (GJ)']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Gas (GJ)   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     18.70
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):           4.91e-08
# Time:                        16:33:27   Log-Likelihood:                -188.31
# No. Observations:                  31   AIC:                             398.6
# Df Residuals:                      20   BIC:                             414.4
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.073e+04    836.217     12.835      0.000    8988.719    1.25e+04
# Sum_woGas (GJ)     4.7672      1.159      4.114      0.001       2.350       7.184
# natural gas       46.3420     72.792      0.637      0.532    -105.499     198.183
# ICAP-1           -22.4864     35.456     -0.634      0.533     -96.446      51.473
# ICAP-2           -60.2802     42.735     -1.411      0.174    -149.423      28.863
# ICAP-3           126.7112     27.151      4.667      0.000      70.075     183.347
# ICAP-4            40.1847     27.436      1.465      0.159     -17.045      97.415
# DAM-1             -9.6809      3.071     -3.152      0.005     -16.088      -3.274
# DAM-2              2.7997      2.421      1.157      0.261      -2.250       7.849
# DAM-3             -6.6331      2.087     -3.178      0.005     -10.987      -2.279
# DAM-4             -2.3753      1.685     -1.410      0.174      -5.889       1.139
# ==============================================================================
# Omnibus:                        1.634   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.512
# Skew:                          -0.483   Prob(JB):                        0.470
# Kurtosis:                       2.514   Cond. No.                     2.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
li_df = li_reg[['Gas (LI)', 
                    #'Coal (LI)',
                    # 'Oil (LI)', 
                    #'Renewables (LI)', 
                    #'Others (LI)',
                    #'Sum (LI)',
                    'Sum_woGas (LI)',
                    #'li_icap',
                    'natural gas', 
                    #'li_dam', 
                    #'Cleared Above LI (%)', 
                    #'UCAP LI (MW)',
                    'ICAP-1', 'ICAP-2', 'ICAP-3', 'ICAP-4',
                    'DAM-1', 'DAM-2', 'DAM-3', 'DAM-4'
                    ]]

# %%
li_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31 entries, 2015-01-01 to 2019-05-01
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gas (LI)        31 non-null     float64
#  1   Sum_woGas (LI)  31 non-null     float64
#  2   natural gas     31 non-null     float64
#  3   ICAP-1          31 non-null     float64
#  4   ICAP-2          31 non-null     float64
#  5   ICAP-3          31 non-null     float64
#  6   ICAP-4          31 non-null     float64
#  7   DAM-1           31 non-null     float64
#  8   DAM-2           31 non-null     float64
#  9   DAM-3           31 non-null     float64
#  10  DAM-4           31 non-null     float64
# dtypes: float64(11)
# memory usage: 2.9 KB

# %%
sns.heatmap(li_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x = li_df.loc[:, li_df.columns != 'Gas (LI)']
y = li_df['Gas (LI)']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Gas (LI)   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     5.998
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):           0.000343
# Time:                        16:33:28   Log-Likelihood:                -129.23
# No. Observations:                  31   AIC:                             280.5
# Df Residuals:                      20   BIC:                             296.2
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4039.1685    326.044     12.388      0.000    3359.053    4719.284
# Sum_woGas (LI)     0.1121      0.202      0.554      0.586      -0.310       0.534
# natural gas      -36.3593     11.233     -3.237      0.004     -59.790     -12.928
# ICAP-1           -34.6343     11.915     -2.907      0.009     -59.488      -9.781
# ICAP-2            17.2733      6.290      2.746      0.012       4.152      30.395
# ICAP-3            -2.8022      3.383     -0.828      0.417      -9.859       4.255
# ICAP-4            15.4688      4.107      3.766      0.001       6.901      24.036
# DAM-1              0.8036      0.390      2.063      0.052      -0.009       1.616
# DAM-2             -0.2001      0.285     -0.703      0.490      -0.794       0.394
# DAM-3             -0.3977      0.173     -2.302      0.032      -0.758      -0.037
# DAM-4             -0.0028      0.178     -0.016      0.987      -0.374       0.369
# ==============================================================================
# Omnibus:                        0.947   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.623   Jarque-Bera (JB):                0.947
# Skew:                           0.362   Prob(JB):                        0.623
# Kurtosis:                       2.543   Cond. No.                     1.45e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
